# %% [markdown]
# # **ABSTRACT**
#
# The purpose of the current notebook is to build a model capable to predict a song's popularity rating based on other song variables. The dataset used is obtained from the following website
#
# https://www.kaggle.com/datasets/maharshipandya/-spotify-tracks-dataset

# %% [markdown]
# # **IMPORT LIBRARIES AND LOAD DATA**

# %%
import os
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import scipy
from scipy import stats
import IPython

# %%
path = './music.csv'
df = pd.read_csv(path, sep = ',', index_col=0)
display(df.head(5))
df.shape
# Out:
#                  track_id                 artists  \
# 0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  duration_ms  explicit  \
# 0                      Comedy          73       230666     False
# 1            Ghost - Acoustic          55       149610     False
# 2              To Begin Again          57       210826     False
# 3  Can't Help Falling In Love          71       201933     False
# 4                     Hold On          82       198853     False
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.676  0.4610    1    -6.746     0       0.1430        0.0322
# 1         0.420  0.1660    1   -17.235     1       0.0763        0.9240
# 2         0.438  0.3590    0    -9.734     1       0.0557        0.2100
# 3         0.266  0.0596    0   -18.515     1       0.0363        0.9050
# 4         0.618  0.4430    2    -9.681     1       0.0526        0.4690
#
#    instrumentalness  liveness  valence    tempo  time_signature track_genre
# 0          0.000001    0.3580    0.715   87.917               4    acoustic
# 1          0.000006    0.1010    0.267   77.489               4    acoustic
# 2          0.000000    0.1170    0.120   76.332               4    acoustic
# 3          0.000071    0.1320    0.143  181.740               3    acoustic
# 4          0.000000    0.0829    0.167  119.949               4    acoustic
# (114000, 20)

# %% [markdown]
# # **MISSING AND DUPLICATE VALUES**

# %%
# Search for unique and missing values
display(df.nunique().to_frame().T.set_index(pd.Index(['unique_value_count'])))
df.isnull().sum().to_frame().T.set_index(pd.Index(['missing_value_count']))
# Out:
#                     track_id  artists  album_name  track_name  popularity  \
# unique_value_count     89741    31437       46589       73608         101
#
#                     duration_ms  explicit  danceability  energy  key  \
# unique_value_count        50697         2          1174    2083   12
#
#                     loudness  mode  speechiness  acousticness  \
# unique_value_count     19480     2         1489          5061
#
#                     instrumentalness  liveness  valence  tempo  \
# unique_value_count              5346      1722     1790  45653
#
#                     time_signature  track_genre
# unique_value_count               5          114
#                      track_id  artists  album_name  track_name  popularity  \
# missing_value_count         0        1           1           1           0
#
#                      duration_ms  explicit  danceability  energy  key  \
# missing_value_count            0         0             0       0    0
#
#                      loudness  mode  speechiness  acousticness  \
# missing_value_count         0     0            0             0
#
#                      instrumentalness  liveness  valence  tempo  \
# missing_value_count                 0         0        0      0
#
#                      time_signature  track_genre
# missing_value_count               0            0

# %%
df[df.isnull().any(axis = 1)]
# Out:
#                      track_id artists album_name track_name  popularity  \
# 65900  1kR4gIb7nGxHPI3D2ifs59     NaN        NaN        NaN           0
#
#        duration_ms  explicit  danceability  energy  key  loudness  mode  \
# 65900            0     False         0.501   0.583    7     -9.46     0
#
#        speechiness  acousticness  instrumentalness  liveness  valence  \
# 65900       0.0605          0.69           0.00396    0.0747    0.734
#
#          tempo  time_signature track_genre
# 65900  138.391               4       k-pop

# %% [markdown]
# There is only one row with missing values in the entire dataset, and those missing values correspond to variables 'artists', 'album_name' and 'track_name'. As these variables probably won't be used for the analysis, no action is taken towards the row at hand.
#
# Nevertheless, it seems odd that the number of unique values for the variable 'track_id' does not match the number of rows of the dataset. This is studied below.

# %%
# Search for duplicate values
display(df[df.duplicated(keep = 'first')].head())
df[df.duplicated(keep = 'first')].shape
# Out:
#                     track_id                 artists          album_name  \
# 1925  0CDucx9lKxuCZplLXUz0iX  Buena Onda Reggae Club             Disco 2
# 2155  2aibwv5hGXSgw7Yru8IYTO   Red Hot Chili Peppers    Stadium Arcadium
# 3738  7mULVp0DJrI2Nd6GesLvxn            Joy Division  Timeless Rock Hits
# 4648  6d3RIvHfVkoOtW1WHXmbX3         Little Symphony            Serenity
# 5769  481beimUiUnMUzSbOAFcUT            SUPER BEAVER       突破口 / 自慢になりたい
#
#                    track_name  popularity  duration_ms  explicit  \
# 1925         Song for Rollins          16       219346     False
# 2155            Snow (Hey Oh)          80       334666     False
# 3738  Love Will Tear Us Apart           0       204621     False
# 4648                   Margot          27        45714     False
# 5769                      突破口          54       255080     False
#
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 1925         0.841   0.577    0    -7.544     1       0.0438      0.238000
# 2155         0.427   0.900   11    -3.674     1       0.0499      0.116000
# 3738         0.524   0.902    2    -8.662     1       0.0368      0.000989
# 4648         0.269   0.142    0   -23.695     1       0.0509      0.866000
# 5769         0.472   0.994    8    -1.786     1       0.1140      0.025900
#
#       instrumentalness  liveness  valence    tempo  time_signature  \
# 1925          0.860000    0.0571    0.843   90.522               4
# 2155          0.000017    0.1190    0.599  104.655               4
# 3738          0.695000    0.1370    0.907  146.833               4
# 4648          0.904000    0.1140    0.321   67.872               3
# 5769          0.000000    0.0535    0.262  103.512               4
#
#       track_genre
# 1925     afrobeat
# 2155     alt-rock
# 3738  alternative
# 4648      ambient
# 5769        anime
# (450, 20)

# %%
df.drop_duplicates(inplace= True)
print (df.shape)
df[df.duplicated()]
# Out:
# (113550, 20)
# Empty DataFrame
# Columns: [track_id, artists, album_name, track_name, popularity, duration_ms, explicit, danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, tempo, time_signature, track_genre]
# Index: []

# %% [markdown]
# There were 450 duplicate valures in the dataset. which are now dropped, modifying the original dataset.
#
# The only column value that should not be repeated throughtout the current dataset is track_id, as all the other ones are variables that could be repeated between tracks. Therefore, duplicates are looked for considering only the track_id column.

# %%
# CELL REFERENCED BELOW

# Get duplicated rows ordered by track ID, so as to identify differences between rows with the same track ID
df_duplicates = df[df.duplicated(subset=['track_id'],keep=False)].sort_values(axis=0, by='track_id')
display (df_duplicates)

# From duplicate dataset preview, it appears the only difference between track_id duplicates is in the column track_genre.
duplicates_set = set()

# Generate a set with track_ids that have duplicates
for row in df_duplicates.index:
    duplicates_set.add(df_duplicates.loc[row].track_id)


# Check if duplicate values differ only in track_genre column. If so, problem_tracks should remain an empty list.
problem_tracks = []

for track_id in duplicates_set:
    l = df_duplicates[df_duplicates['track_id'] == track_id].nunique().to_list() # generate a list with the number of unique values for every column of duplicate tracks
    if sum(l[0:-1]) != 19:
        problem_tracks.append(track_id) # There are 20 values in the list, so if the only difference is in track_genre (last column), the sum of the first values should always be 19

len(problem_tracks)
# Out:
#                       track_id            artists  \
# 15028   001APMDOl3qtx1526T11n1  Pink Sweat$;Kirby
# 103211  001APMDOl3qtx1526T11n1  Pink Sweat$;Kirby
# 85578   001YQlnDSduXd5LgBd66gT        Soda Stereo
# 100420  001YQlnDSduXd5LgBd66gT        Soda Stereo
# 2106    003vvx7Niy0yvhvHt4a68B        The Killers
# ...                        ...                ...
# 22326   7zv2vmZq8OjS54BxFzI2wM             Attila
# 72679   7zv2vmZq8OjS54BxFzI2wM             Attila
# 3100    7zwn1eykZtZ5LODrf7c0tS  The Neighbourhood
# 2004    7zwn1eykZtZ5LODrf7c0tS  The Neighbourhood
# 91401   7zwn1eykZtZ5LODrf7c0tS  The Neighbourhood
#
#                                              album_name  \
# 15028                                           New RnB
# 103211                                          New RnB
# 85578                          Soda Stereo (Remastered)
# 100420                         Soda Stereo (Remastered)
# 2106                                           Hot Fuss
# ...                                                 ...
# 22326                     Soundtrack to a Party (Bonus)
# 72679                     Soundtrack to a Party (Bonus)
# 3100    Hard To Imagine The Neighbourhood Ever Changing
# 2004    Hard To Imagine The Neighbourhood Ever Changing
# 91401   Hard To Imagine The Neighbourhood Ever Changing
#
#                                       track_name  popularity  duration_ms  \
# 15028                                     Better           0       176320
# 103211                                    Better           0       176320
# 85578   El Tiempo Es Dinero - Remasterizado 2007          38       177266
# 100420  El Tiempo Es Dinero - Remasterizado 2007          38       177266
# 2106                              Mr. Brightside          86       222973
# ...                                          ...         ...          ...
# 22326                       Lets Start the Party          25       125859
# 72679                       Lets Start the Party          25       125859
# 3100                          You Get Me So High          83       153000
# 2004                          You Get Me So High          83       153000
# 91401                         You Get Me So High          83       153000
#
#         explicit  danceability  energy  key  loudness  mode  speechiness  \
# 15028      False         0.613   0.471    1    -6.644     0       0.1070
# 103211     False         0.613   0.471    1    -6.644     0       0.1070
# 85578      False         0.554   0.921    2    -4.589     1       0.0758
# 100420     False         0.554   0.921    2    -4.589     1       0.0758
# 2106       False         0.352   0.911    1    -5.230     1       0.0747
# ...          ...           ...     ...  ...       ...   ...          ...
# 22326       True         0.592   0.932    1    -5.412     1       0.0558
# 72679       True         0.592   0.932    1    -5.412     1       0.0558
# 3100       False         0.551   0.881    7    -6.099     0       0.0542
# 2004       False         0.551   0.881    7    -6.099     0       0.0542
# 91401      False         0.551   0.881    7    -6.099     0       0.0542
#
#         acousticness  instrumentalness  liveness  valence    tempo  \
# 15028       0.316000          0.000001    0.1170    0.406  143.064
# 103211      0.316000          0.000001    0.1170    0.406  143.064
# 85578       0.019400          0.088100    0.3290    0.700  183.571
# 100420      0.019400          0.088100    0.3290    0.700  183.571
# 2106        0.001210          0.000000    0.0995    0.236  148.033
# ...              ...               ...       ...      ...      ...
# 22326       0.000005          0.859000    0.0730    0.677  133.987
# 72679       0.000005          0.859000    0.0730    0.677  133.987
# 3100        0.186000          0.079100    0.1520    0.387   88.036
# 2004        0.186000          0.079100    0.1520    0.387   88.036
# 91401       0.186000          0.079100    0.1520    0.387   88.036
#
#         time_signature  track_genre
# 15028                4        chill
# 103211               4         soul
# 85578                1    punk-rock
# 100420               1          ska
# 2106                 4     alt-rock
# ...                ...          ...
# 22326                4  death-metal
# 72679                4    metalcore
# 3100                 4  alternative
# 2004                 4     alt-rock
# 91401                4         rock
#
# [40108 rows x 20 columns]
# 720

# %%
print (len(duplicates_set))
print (len(problem_tracks))

# There are 16299 tracks that appear more than once. 
# From these tracks, 15921 are tracks that appear more than once with different genres. This is, all values are the same except for track_genre
# The other 720 are tracks which differ in another column, though they may also differ in track_genre. Below, it is checked if this column is popularity

tracks_diff_pop = set()

for track_id in problem_tracks:
    df_problem = df_duplicates[df_duplicates['track_id'] == track_id].nunique()
    
    if df_problem['popularity'] != 1 and df_problem['track_genre'] != 1 and sum(df_problem['track_id' : 'track_name']) == 4 and sum(df_problem['duration_ms' : 'time_signature']) == 14:
        tracks_diff_pop.add(track_id)   

print (len(tracks_diff_pop))
# Out:
# 16299
# 720
# 720

# %% [markdown]
# The length of problem_tracks is the same as the length of tracks_diff_pop (720 tracks). This means that the 720 duplicate tracks which differ in columns other than track_genre, actually ONLY differ both in popularity and track genre, but differ in no other column.

# %%
# Find the popularity range for the tracks with multiple values of popularity
problem_tracks_dict = {}
for track_id in problem_tracks:
    min_pop = df_duplicates[df_duplicates['track_id'] == track_id].min()['popularity']
    max_pop = df_duplicates[df_duplicates['track_id'] == track_id].max()['popularity']
    problem_tracks_dict[track_id] = max_pop - min_pop

#print (problem_tracks_dict.values())

counter = 0
counter_equal_2 = 0
for i in problem_tracks_dict.values():
    if i > 2:
        counter += 1
    elif i == 2:
        counter_equal_2 += 1

print (f'There are {counter} tracks with a popularity range greater than two points')
print (f'There are {counter_equal_2} tracks with a popularity range of two points')

for track_id in problem_tracks_dict:
    if problem_tracks_dict[track_id] > 2:
        display (df_duplicates [df_duplicates['track_id'] == track_id])
# Out:
# There are 30 tracks with a popularity range greater than two points
# There are 17 tracks with a popularity range of two points
#                      track_id         artists album_name track_name  \
# 91964  4KPi4VNvPOfKqIp1sx19Xf  Arctic Monkeys    The Car  Big Ideas
# 38034  4KPi4VNvPOfKqIp1sx19Xf  Arctic Monkeys    The Car  Big Ideas
# 57794  4KPi4VNvPOfKqIp1sx19Xf  Arctic Monkeys    The Car  Big Ideas
#
#        popularity  duration_ms  explicit  danceability  energy  key  loudness  \
# 91964          41       237984     False         0.548   0.328    9    -9.973
# 38034           0       237984     False         0.548   0.328    9    -9.973
# 57794           0       237984     False         0.548   0.328    9    -9.973
#
#        mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 91964     0       0.0296         0.663           0.00365    0.0972    0.343
# 38034     0       0.0296         0.663           0.00365    0.0972    0.343
# 57794     0       0.0296         0.663           0.00365    0.0972    0.343
#
#         tempo  time_signature track_genre
# 91964  67.023               3        rock
# 38034  67.023               3      garage
# 57794  67.023               3       indie
#                       track_id        artists album_name track_name  \
# 109219  2ivnsOi3RcEbskFvTS9zt3  Boris Brejcha  Timelapse  Timelapse
# 73087   2ivnsOi3RcEbskFvTS9zt3  Boris Brejcha  Timelapse  Timelapse
#
#         popularity  duration_ms  explicit  danceability  energy  key  \
# 109219          18       493440     False         0.819   0.606    2
# 73087            0       493440     False         0.819   0.606    2
#
#         loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 109219   -10.601     1        0.111      0.000716             0.864     0.111
# 73087    -10.601     1        0.111      0.000716             0.864     0.111
#
#         valence    tempo  time_signature     track_genre
# 109219    0.253  125.007               4          techno
# 73087     0.253  125.007               4  minimal-techno
#                       track_id     artists album_name track_name  popularity  \
# 56302   6mPet122yXpp6X8iTiNVo9  Anupam Roy     Mehman     Mehman           4
# 55804   6mPet122yXpp6X8iTiNVo9  Anupam Roy     Mehman     Mehman           4
# 99251   6mPet122yXpp6X8iTiNVo9  Anupam Roy     Mehman     Mehman          16
# 65850   6mPet122yXpp6X8iTiNVo9  Anupam Roy     Mehman     Mehman           4
# 57551   6mPet122yXpp6X8iTiNVo9  Anupam Roy     Mehman     Mehman           4
# 102251  6mPet122yXpp6X8iTiNVo9  Anupam Roy     Mehman     Mehman          16
#
#         duration_ms  explicit  danceability  energy  key  loudness  mode  \
# 56302        270937     False         0.603   0.783    6    -6.012     1
# 55804        270937     False         0.603   0.783    6    -6.012     1
# 99251        270937     False         0.603   0.783    6    -6.012     1
# 65850        270937     False         0.603   0.783    6    -6.012     1
# 57551        270937     False         0.603   0.783    6    -6.012     1
# 102251       270937     False         0.603   0.783    6    -6.012     1
#
#         speechiness  acousticness  instrumentalness  liveness  valence  \
# 56302        0.0486         0.131          0.000042     0.234    0.703
# 55804        0.0486         0.131          0.000042     0.234    0.703
# 99251        0.0486         0.131          0.000042     0.234    0.703
# 65850        0.0486         0.131          0.000042     0.234    0.703
# 57551        0.0486         0.131          0.000042     0.234    0.703
# 102251       0.0486         0.131          0.000042     0.234    0.703
#
#           tempo  time_signature        track_genre
# 56302   127.981               4          indie-pop
# 55804   127.981               4             indian
# 99251   127.981               4  singer-songwriter
# 65850   127.981               4              k-pop
# 57551   127.981               4              indie
# 102251  127.981               4         songwriter
#                      track_id         artists  \
# 91909  7A7FsIDnBMnz1PAnSOxUdh  Arctic Monkeys
# 57713  7A7FsIDnBMnz1PAnSOxUdh  Arctic Monkeys
# 38019  7A7FsIDnBMnz1PAnSOxUdh  Arctic Monkeys
#
#                              album_name  track_name  popularity  duration_ms  \
# 91909  I Ain't Quite Where I Think I Am  Body Paint          61       290584
# 57713  I Ain't Quite Where I Think I Am  Body Paint          58       290584
# 38019  I Ain't Quite Where I Think I Am  Body Paint          58       290584
#
#        explicit  danceability  energy  key  loudness  mode  speechiness  \
# 91909     False         0.556   0.315    7   -11.651     0       0.0625
# 57713     False         0.556   0.315    7   -11.651     0       0.0625
# 38019     False         0.556   0.315    7   -11.651     0       0.0625
#
#        acousticness  instrumentalness  liveness  valence    tempo  \
# 91909         0.568               0.0    0.0774    0.256  143.327
# 57713         0.568               0.0    0.0774    0.256  143.327
# 38019         0.568               0.0    0.0774    0.256  143.327
#
#        time_signature track_genre
# 91909               4        rock
# 57713               4       indie
# 38019               4      garage
#                       track_id           artists         album_name  \
# 83287   2PVA13ykYYHeXKlIsx2Vjk  Armin van Buuren  Feel Again, Pt. 2
# 110117  2PVA13ykYYHeXKlIsx2Vjk  Armin van Buuren  Feel Again, Pt. 2
#
#        track_name  popularity  duration_ms  explicit  danceability  energy  \
# 83287        Clap           0       150002     False         0.647    0.97
# 110117       Clap           3       150002     False         0.647    0.97
#
#         key  loudness  mode  speechiness  acousticness  instrumentalness  \
# 83287     9    -3.417     1        0.134       0.00795             0.594
# 110117    9    -3.417     1        0.134       0.00795             0.594
#
#         liveness  valence   tempo  time_signature        track_genre
# 83287      0.411    0.122  130.25               4  progressive-house
# 110117     0.411    0.122  130.25               4             trance
#                      track_id      artists           album_name  \
# 79019  2s3Hr38fRfDRj9JWVP494L  OneRepublic  Holidays Are Coming
# 91069  2s3Hr38fRfDRj9JWVP494L  OneRepublic  Holidays Are Coming
#
#                   track_name  popularity  duration_ms  explicit  danceability  \
# 79019  Christmas Without You           7       197146     False         0.262
# 91069  Christmas Without You          14       197146     False         0.262
#
#        energy  key  loudness  mode  speechiness  acousticness  \
# 79019   0.677    7    -5.645     1       0.0528         0.447
# 91069   0.677    7    -5.645     1       0.0528         0.447
#
#        instrumentalness  liveness  valence    tempo  time_signature  \
# 79019               0.0     0.205    0.365  207.478               3
# 91069               0.0     0.205    0.365  207.478               3
#
#       track_genre
# 79019       piano
# 91069        rock
#                       track_id                        artists    album_name  \
# 110956  7nudwi49ZHlgt6AtNNgVnJ  Tritonal;HALIENE;SCHALA;Jorza  Tritonia 400
# 29690   7nudwi49ZHlgt6AtNNgVnJ  Tritonal;HALIENE;SCHALA;Jorza  Tritonia 400
# 28926   7nudwi49ZHlgt6AtNNgVnJ  Tritonal;HALIENE;SCHALA;Jorza  Tritonia 400
#
#                           track_name  popularity  duration_ms  explicit  \
# 110956  Long Way Home (Tritonia 400)          17       304390     False
# 29690   Long Way Home (Tritonia 400)           0       304390     False
# 28926   Long Way Home (Tritonia 400)           0       304390     False
#
#         danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 110956         0.584    0.77   11    -3.514     0       0.0644        0.0113
# 29690          0.584    0.77   11    -3.514     0       0.0644        0.0113
# 28926          0.584    0.77   11    -3.514     0       0.0644        0.0113
#
#         instrumentalness  liveness  valence    tempo  time_signature  \
# 110956          0.000034     0.418    0.411  129.913               4
# 29690           0.000034     0.418    0.411  129.913               4
# 28926           0.000034     0.418    0.411  129.913               4
#
#        track_genre
# 110956      trance
# 29690      dubstep
# 28926          dub
#                       track_id  \
# 100031  7FjBkz3OJiknpx1jtNkIFs
# 85094   7FjBkz3OJiknpx1jtNkIFs
#
#                                                   artists  \
# 100031  Joe Strummer;Scott Shields;Martin Slattery;Ric...
# 85094   Joe Strummer;Scott Shields;Martin Slattery;Ric...
#
#                           album_name                  track_name  popularity  \
# 100031  Cinema Sounds of Hans Zimmer  Minstrel Boy - Film Verson           7
# 85094   Cinema Sounds of Hans Zimmer  Minstrel Boy - Film Verson           4
#
#         duration_ms  explicit  danceability  energy  key  loudness  mode  \
# 100031       337173     False         0.351   0.674    7    -9.068     1
# 85094        337173     False         0.351   0.674    7    -9.068     1
#
#         speechiness  acousticness  instrumentalness  liveness  valence  \
# 100031       0.0376       0.00644             0.419    0.0536    0.414
# 85094        0.0376       0.00644             0.419    0.0536    0.414
#
#           tempo  time_signature track_genre
# 100031  174.162               3         ska
# 85094   174.162               3   punk-rock
#                      track_id         artists album_name  \
# 38033  1zx6GSqLYI2ynzAHnPRKBR  Arctic Monkeys    The Car
# 91962  1zx6GSqLYI2ynzAHnPRKBR  Arctic Monkeys    The Car
# 57793  1zx6GSqLYI2ynzAHnPRKBR  Arctic Monkeys    The Car
#
#                            track_name  popularity  duration_ms  explicit  \
# 38033  There’d Better Be A Mirrorball           0       265798     False
# 91962  There’d Better Be A Mirrorball          41       265798     False
# 57793  There’d Better Be A Mirrorball           0       265798     False
#
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 38033         0.521   0.365    3   -10.914     1       0.0317         0.626
# 91962         0.521   0.365    3   -10.914     1       0.0317         0.626
# 57793         0.521   0.365    3   -10.914     1       0.0317         0.626
#
#        instrumentalness  liveness  valence    tempo  time_signature  \
# 38033             0.012     0.185    0.324  143.789               4
# 91962             0.012     0.185    0.324  143.789               4
# 57793             0.012     0.185    0.324  143.789               4
#
#       track_genre
# 38033      garage
# 91962        rock
# 57793       indie
#                       track_id                             artists  \
# 110938  1Wt8OoQoQ2DsoPHs0TdOHn  Seven Lions;Vancouver Sleep Clinic
# 29349   1Wt8OoQoQ2DsoPHs0TdOHn  Seven Lions;Vancouver Sleep Clinic
# 28447   1Wt8OoQoQ2DsoPHs0TdOHn  Seven Lions;Vancouver Sleep Clinic
#
#              album_name                                 track_name  \
# 110938  Beyond The Veil  Call On Me (feat. Vancouver Sleep Clinic)
# 29349   Beyond The Veil  Call On Me (feat. Vancouver Sleep Clinic)
# 28447   Beyond The Veil  Call On Me (feat. Vancouver Sleep Clinic)
#
#         popularity  duration_ms  explicit  danceability  energy  key  \
# 110938           8       293122     False         0.323   0.698    2
# 29349            0       293122     False         0.323   0.698    2
# 28447            0       293122     False         0.323   0.698    2
#
#         loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 110938    -5.498     1       0.0449        0.0801               0.0     0.122
# 29349     -5.498     1       0.0449        0.0801               0.0     0.122
# 28447     -5.498     1       0.0449        0.0801               0.0     0.122
#
#         valence    tempo  time_signature track_genre
# 110938    0.105  145.987               4      trance
# 29349     0.105  145.987               4     dubstep
# 28447     0.105  145.987               4         dub
#                      track_id                artists          album_name  \
# 2034   0v8tmDMQrTMavluubqAJo4  Red Hot Chili Peppers  80s Bangers Vol. 2
# 37048  0v8tmDMQrTMavluubqAJo4  Red Hot Chili Peppers  80s Bangers Vol. 2
# 71044  0v8tmDMQrTMavluubqAJo4  Red Hot Chili Peppers  80s Bangers Vol. 2
# 91130  0v8tmDMQrTMavluubqAJo4  Red Hot Chili Peppers  80s Bangers Vol. 2
# 3022   0v8tmDMQrTMavluubqAJo4  Red Hot Chili Peppers  80s Bangers Vol. 2
#
#                        track_name  popularity  duration_ms  explicit  \
# 2034   Higher Ground - Remastered           1       202053     False
# 37048  Higher Ground - Remastered           1       202053     False
# 71044  Higher Ground - Remastered           1       202053     False
# 91130  Higher Ground - Remastered           4       202053     False
# 3022   Higher Ground - Remastered           1       202053     False
#
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 2034          0.476   0.979    4    -3.504     0        0.133       0.00142
# 37048         0.476   0.979    4    -3.504     0        0.133       0.00142
# 71044         0.476   0.979    4    -3.504     0        0.133       0.00142
# 91130         0.476   0.979    4    -3.504     0        0.133       0.00142
# 3022          0.476   0.979    4    -3.504     0        0.133       0.00142
#
#        instrumentalness  liveness  valence    tempo  time_signature  \
# 2034            0.00686    0.0944    0.394  140.408               4
# 37048           0.00686    0.0944    0.394  140.408               4
# 71044           0.00686    0.0944    0.394  140.408               4
# 91130           0.00686    0.0944    0.394  140.408               4
# 3022            0.00686    0.0944    0.394  140.408               4
#
#        track_genre
# 2034      alt-rock
# 37048         funk
# 71044        metal
# 91130         rock
# 3022   alternative
#                       track_id                 artists         album_name  \
# 110108  6tDtuaCX0sIea6o8Qmpyae  Armin van Buuren;Husky  Feel Again, Pt. 2
# 83276   6tDtuaCX0sIea6o8Qmpyae  Armin van Buuren;Husky  Feel Again, Pt. 2
#
#           track_name  popularity  duration_ms  explicit  danceability  energy  \
# 110108  Shot At Love           5       202677     False          0.54   0.916
# 83276   Shot At Love           0       202677     False          0.54   0.916
#
#         key  loudness  mode  speechiness  acousticness  instrumentalness  \
# 110108    6    -6.275     1       0.0382       0.00237           0.00015
# 83276     6    -6.275     1       0.0382       0.00237           0.00015
#
#         liveness  valence    tempo  time_signature        track_genre
# 110108    0.0622    0.262  126.999               4             trance
# 83276     0.0622    0.262  126.999               4  progressive-house
#                      track_id         artists album_name   track_name  \
# 38027  5fClRRa7P9nPIpstj50veV  Arctic Monkeys    The Car  Mr Schwartz
# 57790  5fClRRa7P9nPIpstj50veV  Arctic Monkeys    The Car  Mr Schwartz
# 91955  5fClRRa7P9nPIpstj50veV  Arctic Monkeys    The Car  Mr Schwartz
#
#        popularity  duration_ms  explicit  danceability  energy  key  loudness  \
# 38027           0       210012     False         0.569   0.335   11   -13.637
# 57790           0       210012     False         0.569   0.335   11   -13.637
# 91955          40       210012     False         0.569   0.335   11   -13.637
#
#        mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 38027     0       0.0322         0.802             0.018    0.0834    0.388
# 57790     0       0.0322         0.802             0.018    0.0834    0.388
# 91955     0       0.0322         0.802             0.018    0.0834    0.388
#
#          tempo  time_signature track_genre
# 38027  127.587               4      garage
# 57790  127.587               4       indie
# 91955  127.587               4        rock
#                       track_id                      artists  \
# 110111  2i6vQrYVULLekBceqmCNwT  Armin van Buuren;Simon Ward
# 83268   2i6vQrYVULLekBceqmCNwT  Armin van Buuren;Simon Ward
#
#                album_name        track_name  popularity  duration_ms  \
# 110111  Feel Again, Pt. 2  Hey (I Miss You)           3       199522
# 83268   Feel Again, Pt. 2  Hey (I Miss You)           0       199522
#
#         explicit  danceability  energy  key  loudness  mode  speechiness  \
# 110111     False         0.615    0.88    5     -3.72     1       0.0356
# 83268      False         0.615    0.88    5     -3.72     1       0.0356
#
#         acousticness  instrumentalness  liveness  valence    tempo  \
# 110111      0.000377          0.000929    0.0464    0.416  120.049
# 83268       0.000377          0.000929    0.0464    0.416  120.049
#
#         time_signature        track_genre
# 110111               4             trance
# 83268                4  progressive-house
#                       track_id           artists         album_name  \
# 83275   5fMy36xPHP4PEgsirxLmma  Armin van Buuren  Feel Again, Pt. 2
# 110112  5fMy36xPHP4PEgsirxLmma  Armin van Buuren  Feel Again, Pt. 2
#
#                  track_name  popularity  duration_ms  explicit  danceability  \
# 83275   Something Beautiful           0       154336     False         0.581
# 110112  Something Beautiful           5       154336     False         0.581
#
#         energy  key  loudness  mode  speechiness  acousticness  \
# 83275    0.821    6    -4.702     1        0.033       0.00981
# 110112   0.821    6    -4.702     1        0.033       0.00981
#
#         instrumentalness  liveness  valence    tempo  time_signature  \
# 83275                0.0     0.226    0.514  120.733               4
# 110112               0.0     0.226    0.514  120.733               4
#
#               track_genre
# 83275   progressive-house
# 110112             trance
#                       track_id                           artists  \
# 110124  0aeqKlSGQgi6Dwr87N3LNq  Armin van Buuren;Blasterjaxx;24h
# 83280   0aeqKlSGQgi6Dwr87N3LNq  Armin van Buuren;Blasterjaxx;24h
#
#                album_name track_name  popularity  duration_ms  explicit  \
# 110124  Feel Again, Pt. 2   Superman           5       204250     False
# 83280   Feel Again, Pt. 2   Superman           0       204250     False
#
#         danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 110124         0.403   0.884    6     -6.25     0        0.126        0.0115
# 83280          0.403   0.884    6     -6.25     0        0.126        0.0115
#
#         instrumentalness  liveness  valence    tempo  time_signature  \
# 110124          0.000069     0.805    0.436  103.501               3
# 83280           0.000069     0.805    0.436  103.501               3
#
#               track_genre
# 110124             trance
# 83280   progressive-house
#                      track_id                       artists  \
# 19042  014SIjoLDG1Ku19c5FlDYh  Creedence Clearwater Revival
# 91138  014SIjoLDG1Ku19c5FlDYh  Creedence Clearwater Revival
#
#                album_name            track_name  popularity  duration_ms  \
# 19042  Pumpkin Patch Hits  I Put A Spell On You           0       271786
# 91138  Pumpkin Patch Hits  I Put A Spell On You           3       271786
#
#        explicit  danceability  energy  key  loudness  mode  speechiness  \
# 19042     False         0.393   0.732    4    -8.188     0       0.0295
# 91138     False         0.393   0.732    4    -8.188     0       0.0295
#
#        acousticness  instrumentalness  liveness  valence   tempo  \
# 19042       0.00471             0.123    0.0979    0.621  100.41
# 91138       0.00471             0.123    0.0979    0.621  100.41
#
#        time_signature track_genre
# 19042               4     country
# 91138               4        rock
#                      track_id         artists album_name  track_name  \
# 57791  42GuKw49pPxNAkIhWGwgFs  Arctic Monkeys    The Car  Body Paint
# 91958  42GuKw49pPxNAkIhWGwgFs  Arctic Monkeys    The Car  Body Paint
# 38029  42GuKw49pPxNAkIhWGwgFs  Arctic Monkeys    The Car  Body Paint
#
#        popularity  duration_ms  explicit  danceability  energy  key  loudness  \
# 57791           0       290584     False         0.556   0.315    7   -11.651
# 91958          39       290584     False         0.556   0.315    7   -11.651
# 38029           0       290584     False         0.556   0.315    7   -11.651
#
#        mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 57791     0       0.0625         0.568               0.0    0.0774    0.256
# 91958     0       0.0625         0.568               0.0    0.0774    0.256
# 38029     0       0.0625         0.568               0.0    0.0774    0.256
#
#          tempo  time_signature track_genre
# 57791  143.327               4       indie
# 91958  143.327               4        rock
# 38029  143.327               4      garage
#                      track_id         artists album_name track_name  \
# 57723  0C6dSPCqwKqwos6s1CrDrh  Arctic Monkeys    The Car    The Car
# 38026  0C6dSPCqwKqwos6s1CrDrh  Arctic Monkeys    The Car    The Car
# 91954  0C6dSPCqwKqwos6s1CrDrh  Arctic Monkeys    The Car    The Car
#
#        popularity  duration_ms  explicit  danceability  energy  key  loudness  \
# 57723           0       198554     False         0.428   0.365    4   -11.889
# 38026           0       198554     False         0.428   0.365    4   -11.889
# 91954          42       198554     False         0.428   0.365    4   -11.889
#
#        mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 57723     0       0.0276          0.78            0.0033     0.113    0.236
# 38026     0       0.0276          0.78            0.0033     0.113    0.236
# 91954     0       0.0276          0.78            0.0033     0.113    0.236
#
#         tempo  time_signature track_genre
# 57723  94.033               3       indie
# 38026  94.033               3      garage
# 91954  94.033               3        rock
#                      track_id         artists album_name  \
# 57792  5hljqZrl0h7RcIhUnOPuve  Arctic Monkeys    The Car
# 38030  5hljqZrl0h7RcIhUnOPuve  Arctic Monkeys    The Car
# 91956  5hljqZrl0h7RcIhUnOPuve  Arctic Monkeys    The Car
#
#                         track_name  popularity  duration_ms  explicit  \
# 57792  Sculptures Of Anything Goes           0       239151     False
# 38030  Sculptures Of Anything Goes           0       239151     False
# 91956  Sculptures Of Anything Goes          44       239151     False
#
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 57792         0.591   0.309    4   -11.087     0       0.0287         0.704
# 38030         0.591   0.309    4   -11.087     0       0.0287         0.704
# 91956         0.591   0.309    4   -11.087     0       0.0287         0.704
#
#        instrumentalness  liveness  valence   tempo  time_signature track_genre
# 57792            0.0122     0.102    0.257  71.573               4       indie
# 38030            0.0122     0.102    0.257  71.573               4      garage
# 91956            0.0122     0.102    0.257  71.573               4        rock
#                       track_id                       artists  \
# 83265   1UktZnwuS1reRmRtli8QS9  Armin van Buuren;Maia Wright
# 110113  1UktZnwuS1reRmRtli8QS9  Armin van Buuren;Maia Wright
#
#                album_name     track_name  popularity  duration_ms  explicit  \
# 83265   Feel Again, Pt. 2  One More Time           0       148095     False
# 110113  Feel Again, Pt. 2  One More Time           5       148095     False
#
#         danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 83265          0.579   0.764    0     -5.55     1       0.0512        0.0995
# 110113         0.579   0.764    0     -5.55     1       0.0512        0.0995
#
#         instrumentalness  liveness  valence    tempo  time_signature  \
# 83265            0.00174     0.273    0.289  126.162               4
# 110113           0.00174     0.273    0.289  126.162               4
#
#               track_genre
# 83265   progressive-house
# 110113             trance
#                      track_id         artists album_name     track_name  \
# 57724  0z5x3VmmQ7cyTeOP7VAf3T  Arctic Monkeys    The Car  Perfect Sense
# 38028  0z5x3VmmQ7cyTeOP7VAf3T  Arctic Monkeys    The Car  Perfect Sense
# 91953  0z5x3VmmQ7cyTeOP7VAf3T  Arctic Monkeys    The Car  Perfect Sense
#
#        popularity  duration_ms  explicit  danceability  energy  key  loudness  \
# 57724           0       167379     False          0.52   0.478    4   -10.862
# 38028           0       167379     False          0.52   0.478    4   -10.862
# 91953          40       167379     False          0.52   0.478    4   -10.862
#
#        mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 57724     1       0.0276          0.61           0.00122     0.105    0.545
# 38028     1       0.0276          0.61           0.00122     0.105    0.545
# 91953     1       0.0276          0.61           0.00122     0.105    0.545
#
#         tempo  time_signature track_genre
# 57724  82.932               4       indie
# 38028  82.932               4      garage
# 91953  82.932               4        rock
#                       track_id           artists         album_name  \
# 110133  3LNJXM1TJlksK5WnabNqDg  Armin van Buuren  Feel Again, Pt. 2
# 83288   3LNJXM1TJlksK5WnabNqDg  Armin van Buuren  Feel Again, Pt. 2
#
#                            track_name  popularity  duration_ms  explicit  \
# 110133  Computers Take Over The World           4       152250     False
# 83288   Computers Take Over The World           0       152250     False
#
#         danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 110133         0.777   0.832    1    -5.739     1        0.179       0.00632
# 83288          0.777   0.832    1    -5.739     1        0.179       0.00632
#
#         instrumentalness  liveness  valence    tempo  time_signature  \
# 110133            0.0508      0.12    0.775  139.917               4
# 83288             0.0508      0.12    0.775  139.917               4
#
#               track_genre
# 110133             trance
# 83288   progressive-house
#                      track_id         artists album_name  \
# 38037  1UwUhKmFxGKs59xiWO60Sx  Arctic Monkeys    The Car
# 91965  1UwUhKmFxGKs59xiWO60Sx  Arctic Monkeys    The Car
# 57749  1UwUhKmFxGKs59xiWO60Sx  Arctic Monkeys    The Car
#
#                              track_name  popularity  duration_ms  explicit  \
# 38037  I Ain’t Quite Where I Think I Am           0       191173     False
# 91965  I Ain’t Quite Where I Think I Am          42       191173     False
# 57749  I Ain’t Quite Where I Think I Am           0       191173     False
#
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 38037         0.544   0.337   10    -9.846     1       0.0653         0.357
# 91965         0.544   0.337   10    -9.846     1       0.0653         0.357
# 57749         0.544   0.337   10    -9.846     1       0.0653         0.357
#
#        instrumentalness  liveness  valence    tempo  time_signature  \
# 38037          0.000063     0.085    0.667  192.685               4
# 91965          0.000063     0.085    0.667  192.685               4
# 57749          0.000063     0.085    0.667  192.685               4
#
#       track_genre
# 38037      garage
# 91965        rock
# 57749       indie
#                       track_id                       artists  \
# 110106  3l1cyMgi27bv1KIP10cqOW  Armin van Buuren;Scott Abbot
# 83263   3l1cyMgi27bv1KIP10cqOW  Armin van Buuren;Scott Abbot
#
#                album_name track_name  popularity  duration_ms  explicit  \
# 110106  Feel Again, Pt. 2  I'm Sorry           7       190384     False
# 83263   Feel Again, Pt. 2  I'm Sorry           0       190384     False
#
#         danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 110106         0.596   0.919    9    -6.179     0       0.0485        0.0329
# 83263          0.596   0.919    9    -6.179     0       0.0485        0.0329
#
#         instrumentalness  liveness  valence    tempo  time_signature  \
# 110106          0.000216     0.138    0.218  130.017               4
# 83263           0.000216     0.138    0.218  130.017               4
#
#               track_genre
# 110106             trance
# 83263   progressive-house
#                      track_id         artists album_name track_name  \
# 91961  5ygEUpyZy5qtZ1423zymBW  Arctic Monkeys    The Car  Hello You
# 38031  5ygEUpyZy5qtZ1423zymBW  Arctic Monkeys    The Car  Hello You
# 57746  5ygEUpyZy5qtZ1423zymBW  Arctic Monkeys    The Car  Hello You
#
#        popularity  duration_ms  explicit  danceability  energy  key  loudness  \
# 91961          41       244932     False         0.394   0.452    4    -9.923
# 38031           0       244932     False         0.394   0.452    4    -9.923
# 57746           0       244932     False         0.394   0.452    4    -9.923
#
#        mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 91961     0       0.0321         0.276           0.00998     0.193    0.653
# 38031     0       0.0321         0.276           0.00998     0.193    0.653
# 57746     0       0.0321         0.276           0.00998     0.193    0.653
#
#          tempo  time_signature track_genre
# 91961  169.298               4        rock
# 38031  169.298               4      garage
# 57746  169.298               4       indie
#                       track_id                         artists  \
# 110105  0BhLfxWA4TwGu8bGVKBotN  Armin van Buuren;Philip Strand
# 83260   0BhLfxWA4TwGu8bGVKBotN  Armin van Buuren;Philip Strand
#
#                album_name     track_name  popularity  duration_ms  explicit  \
# 110105  Feel Again, Pt. 2  Roll The Dice          27       155238     False
# 83260   Feel Again, Pt. 2  Roll The Dice           0       155238     False
#
#         danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 110105         0.612   0.731    1    -5.869     0       0.0527         0.057
# 83260          0.612   0.731    1    -5.869     0       0.0527         0.057
#
#         instrumentalness  liveness  valence    tempo  time_signature  \
# 110105               0.0     0.317    0.569  125.916               4
# 83260                0.0     0.317    0.569  125.916               4
#
#               track_genre
# 110105             trance
# 83260   progressive-house
#                       track_id               artists album_name track_name  \
# 109224  65YXrDsZER1jlPAqFS9GDH  Boris Brejcha;Ginger  Timelapse   Darkness
# 73093   65YXrDsZER1jlPAqFS9GDH  Boris Brejcha;Ginger  Timelapse   Darkness
#
#         popularity  duration_ms  explicit  danceability  energy  key  \
# 109224          10       478080     False         0.803   0.686    2
# 73093            0       478080     False         0.803   0.686    2
#
#         loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 109224    -9.289     1       0.0467      0.000513             0.839    0.0985
# 73093     -9.289     1       0.0467      0.000513             0.839    0.0985
#
#         valence    tempo  time_signature     track_genre
# 109224    0.146  124.996               4          techno
# 73093     0.146  124.996               4  minimal-techno
#                       track_id                                    artists  \
# 83262   26rzkGV7pXYOIr4hUg8Mbb  Armin van Buuren;Diane Warren;My Marianne
# 110114  26rzkGV7pXYOIr4hUg8Mbb  Armin van Buuren;Diane Warren;My Marianne
#
#                album_name    track_name  popularity  duration_ms  explicit  \
# 83262   Feel Again, Pt. 2  Live On Love           0       171733     False
# 110114  Feel Again, Pt. 2  Live On Love           3       171733     False
#
#         danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 83262          0.631   0.761   10    -6.289     0       0.0708         0.038
# 110114         0.631   0.761   10    -6.289     0       0.0708         0.038
#
#         instrumentalness  liveness  valence    tempo  time_signature  \
# 83262            0.00001     0.114    0.534  122.698               4
# 110114           0.00001     0.114    0.534  122.698               4
#
#               track_genre
# 83262   progressive-house
# 110114             trance
#                       track_id                                 artists  \
# 110116  6T0e1wKkONiIZQ1FTjMlGZ  Armin van Buuren;Gareth Emery;Owl City
# 83273   6T0e1wKkONiIZQ1FTjMlGZ  Armin van Buuren;Gareth Emery;Owl City
#
#                album_name        track_name  popularity  duration_ms  \
# 110116  Feel Again, Pt. 2  Forever & Always           4       194002
# 83273   Feel Again, Pt. 2  Forever & Always           0       194002
#
#         explicit  danceability  energy  key  loudness  mode  speechiness  \
# 110116     False          0.58   0.921    8    -7.376     1       0.0463
# 83273      False          0.58   0.921    8    -7.376     1       0.0463
#
#         acousticness  instrumentalness  liveness  valence   tempo  \
# 110116       0.00787          0.000081     0.097     0.37  144.98
# 83273        0.00787          0.000081     0.097     0.37  144.98
#
#         time_signature        track_genre
# 110116               4             trance
# 83273                4  progressive-house

# %% [markdown]
# Most tracks which have multiple levels of popularity actually have a popularity range of only one point. For these tracks, considering either minimum or maximum popularity rating will make no difference for the analysis.
#
# Furthermore, there are only 30 tracks with a popularity range greater than two points, 20 of which are tracks of which there is only one appearance with a popularity rating different from zero, while all other appearances have a popularity rating of zero. For these tracks, appearances with popularity ratings of zero are disregarded, keeping only the appearance with a popularity rating different from zero. This will be done by keeping the appearance with maximum popularity rating.
#
# Applying the same criteria for the remaining 10 tracks (tracks which have a popularity range greater than two points but with no appearance with 0 popularity), as well as for the 17 tracks with a popularity range of two points, will make no differece for the analysis, as the popularity ranges are still small.
#
#
# **CONCLUSION:**
#
# **For the 720 tracks with more than one appearance, differing both in track genre and popularity, the appearance with maximum popularity shall be kept, dropping all other appearances.**
# **For the 15921 tracks which differ only in track genre, only the first appearance will be kept**
#
# This is done below

# %%
# Keep tracks with maximum popularity from mentioned 720 tracks (tracks' id stored in problem_tracks)
print (df.shape)
for track_id in problem_tracks:
    max_pop = df_duplicates[df_duplicates['track_id'] == track_id].max()['popularity']
    row = df[(df['popularity'] != max_pop) & (df['track_id'] == track_id)].index
    df = df.drop(row)

df.shape

# OBS:Run cell above titled 'CELL REFERENCED BELOW' for verification. len(problem_tracks) should be 0.
# Out:
# (113550, 20)
# (112567, 20)

# %%
# Remove duplicate values which differ only in track genre
print (df.shape)

df.drop_duplicates(subset=['track_id'], keep = 'first', inplace = True)

df.shape
# Out:
# (112567, 20)
# (89741, 20)

# %%
# Check modifications in current dataframe
print (df.shape)

# Check unique and missing values (number of track_id unique values should match number of rows of the modified dataset)
display(df.nunique().to_frame().T.set_index(pd.Index(['unique_value_count'])))
display (df.isnull().sum().to_frame().T.set_index(pd.Index(['missing_value_count'])))

# Check duplicate values
display (df[df.duplicated(keep='first')])

# Check duplicate values for track_id column
display (df[df.duplicated(subset = ['track_id'], keep='first')])
# Out:
# (89741, 20)
#                     track_id  artists  album_name  track_name  popularity  \
# unique_value_count     89741    31437       46589       73608         101
#
#                     duration_ms  explicit  danceability  energy  key  \
# unique_value_count        50697         2          1174    2083   12
#
#                     loudness  mode  speechiness  acousticness  \
# unique_value_count     19480     2         1489          5061
#
#                     instrumentalness  liveness  valence  tempo  \
# unique_value_count              5346      1722     1790  45653
#
#                     time_signature  track_genre
# unique_value_count               5          113
#                      track_id  artists  album_name  track_name  popularity  \
# missing_value_count         0        1           1           1           0
#
#                      duration_ms  explicit  danceability  energy  key  \
# missing_value_count            0         0             0       0    0
#
#                      loudness  mode  speechiness  acousticness  \
# missing_value_count         0     0            0             0
#
#                      instrumentalness  liveness  valence  tempo  \
# missing_value_count                 0         0        0      0
#
#                      time_signature  track_genre
# missing_value_count               0            0
# Empty DataFrame
# Columns: [track_id, artists, album_name, track_name, popularity, duration_ms, explicit, danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, tempo, time_signature, track_genre]
# Index: []
# Empty DataFrame
# Columns: [track_id, artists, album_name, track_name, popularity, duration_ms, explicit, danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, tempo, time_signature, track_genre]
# Index: []

# %% [markdown]
# # **UNIVARIATE ANALYSIS**

# %%
df.head()
# Out:
#                  track_id                 artists  \
# 0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  duration_ms  explicit  \
# 0                      Comedy          73       230666     False
# 1            Ghost - Acoustic          55       149610     False
# 2              To Begin Again          57       210826     False
# 3  Can't Help Falling In Love          71       201933     False
# 4                     Hold On          82       198853     False
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.676  0.4610    1    -6.746     0       0.1430        0.0322
# 1         0.420  0.1660    1   -17.235     1       0.0763        0.9240
# 2         0.438  0.3590    0    -9.734     1       0.0557        0.2100
# 3         0.266  0.0596    0   -18.515     1       0.0363        0.9050
# 4         0.618  0.4430    2    -9.681     1       0.0526        0.4690
#
#    instrumentalness  liveness  valence    tempo  time_signature track_genre
# 0          0.000001    0.3580    0.715   87.917               4    acoustic
# 1          0.000006    0.1010    0.267   77.489               4    acoustic
# 2          0.000000    0.1170    0.120   76.332               4    acoustic
# 3          0.000071    0.1320    0.143  181.740               3    acoustic
# 4          0.000000    0.0829    0.167  119.949               4    acoustic

# %%
# COLUMN HISTOGRAMS
mpl.style.use('seaborn-deep')

rows = 4
cols = 4
fig,ax1 = plt.subplots(nrows = rows, ncols = cols, figsize = (30,15))

columns = ['popularity', 'duration_ms', 'danceability', 'energy', 'key', 'loudness', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature']

counter = 0
for row in range(rows):
    for col in range(cols):
        if counter <= len(columns) - 1:
            ax1[row,col].set_ylabel('Count', fontsize = 15, fontweight = 'bold', alpha = 0.6 )
            ax1[row,col].grid(True)
            if columns[counter] != 'duration_ms' and columns[counter] != 'instrumentalness':
                ax1[row,col].set_xlabel(columns[counter], fontsize = 15, fontweight = 'bold', alpha = 0.6)
                ax1[row,col].hist(x= df[columns[counter]], bins=15, density=False, orientation='vertical', histtype = 'barstacked', rwidth = 0.75)
            elif columns[counter] == 'duration_ms':
                ax1[row,col].set_xlabel('duration [sec]', fontsize = 15, fontweight = 'bold', alpha = 0.6)
                ax1[row,col].hist(x= df[columns[counter]]/1000, bins=150, density=False, orientation='vertical', histtype = 'barstacked', rwidth = 0.75)
                ax1[row,col].set_xlim(0,1000)
            else:
                ax1[row,col].set_xlabel('instrumentalness', fontsize = 15, fontweight = 'bold', alpha = 0.6)
                ax1[row,col].hist(x= df[columns[counter]], bins=100, density=False, orientation='vertical', histtype = 'barstacked', rwidth = 0.75)
                ax1[row,col].set_xlim(0,df.instrumentalness.median() + df.instrumentalness.std())
            
            counter += 1

plt.yticks(fontsize = 15)
# Out:
# C:\Users\velas\AppData\Local\Temp\ipykernel_23436\2207735790.py:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   mpl.style.use('seaborn-deep')
# (array([0. , 0.2, 0.4, 0.6, 0.8, 1. ]),
#  [Text(0, 0.0, '0.0'),
#   Text(0, 0.2, '0.2'),
#   Text(0, 0.4, '0.4'),
#   Text(0, 0.6000000000000001, '0.6'),
#   Text(0, 0.8, '0.8'),
#   Text(0, 1.0, '1.0')])

# %% [markdown]
# Values for speechiness, instrumentalness and time_signature seem to be fairly constant for the entire dataset, so they probably won't be useful for the analysis.
# Based on distribution alone:
# - Primary variables to consider: duration, danceability, energy, key, valence, tempo
# - Secondary variables to consider: loudness, acousticeness, liveness

# %%
print (f'Instrumentalness median = {df.instrumentalness.median()}')
print (f'Instrumentalness max = {df.instrumentalness.max()}')
print (f'Instrumentalness min = {df.instrumentalness.min()}')
print (f'Instrumentalness mean = {round(df.instrumentalness.mean(),3)}')
print (f'Instrumentalness std = {round(df.instrumentalness.std(),3)}')
# Out:
# Instrumentalness median = 5.8e-05
# Instrumentalness max = 1.0
# Instrumentalness min = 0.0
# Instrumentalness mean = 0.173
# Instrumentalness std = 0.324

# %%
print(df[df['explicit'] == True].track_id.count())
print(df[df['explicit'] == False].track_id.count())

print(df[df['mode'] == 0].track_id.count())
print(df[df['mode'] == 1].track_id.count())
# Out:
# 7704
# 82037
# 32579
# 57162

# %%
# POPULARITY HISTOGRAMS FOR 'MODE' AND 'EXPLICIT' VALUES
mpl.style.use('seaborn-deep')
fig,ax1 = plt.subplots(nrows = 2, ncols = 3, figsize = (30,10))


# POPULARITY HISTOGRAMS FOR 'MODE' 1 AND 0
ax1[0,0].set_ylabel('Count', fontsize = 12, fontweight = 'bold', alpha = 0.6 )
ax1[0,0].set_xlabel('popularity', fontsize = 12, fontweight = 'bold', alpha = 0.6)
df_mode = df[(df['popularity']) & (df['mode'] == 0)]
ax1[0,0].hist(x= df_mode['popularity'], bins=15, density=False, orientation='vertical', histtype = 'barstacked', rwidth = 0.75)
ax1[0,0].set_title ('Popularity histogram for mode = 0', fontsize = 15, fontweight = 'bold', alpha = 0.6)
ax1[0,0].grid(True)

ax1[0,1].set_ylabel('Count', fontsize = 12, fontweight = 'bold', alpha = 0.6 )
ax1[0,1].set_xlabel('popularity', fontsize = 12, fontweight = 'bold', alpha = 0.6)
df_mode = df[(df['popularity']) & (df['mode'] == 1)]
ax1[0,1].hist(x= df_mode['popularity'], bins=15, density=False, orientation='vertical', histtype = 'barstacked', rwidth = 0.75)
ax1[0,1].set_title ('Popularity histogram for mode = 1', fontsize = 15, fontweight = 'bold', alpha = 0.6)
ax1[0,1].grid(True)

ax1[0,2].set_ylabel('Count', fontsize = 12, fontweight = 'bold', alpha = 0.6 )
ax1[0,2].set_xlabel('popularity', fontsize = 12, fontweight = 'bold', alpha = 0.6)
ax1[0,2].hist(x= df['popularity'], bins=15, density=False, orientation='vertical', histtype = 'barstacked', rwidth = 0.75)
ax1[0,2].set_title ('Popularity histogram', fontsize = 15, fontweight = 'bold', alpha = 0.6)
ax1[0,2].grid(True)

# POPULARITY HISTOGRAMS FOR 'EXPLICIT' TRUE AND FALSE
ax1[1,0].set_ylabel('Count', fontsize = 12, fontweight = 'bold', alpha = 0.6 )
ax1[1,0].set_xlabel('popularity', fontsize = 12, fontweight = 'bold', alpha = 0.6)
df_mode = df[(df['popularity']) & (df['explicit'] == True)]
ax1[1,0].hist(x= df_mode['popularity'], bins=15, density=False, orientation='vertical', histtype = 'barstacked', rwidth = 0.75)
ax1[1,0].set_title ('Popularity histogram for explicit = True', fontsize = 15, fontweight = 'bold', alpha = 0.6)
ax1[1,0].grid(True)

ax1[1,1].set_ylabel('Count', fontsize = 12, fontweight = 'bold', alpha = 0.6 )
ax1[1,1].set_xlabel('popularity', fontsize = 12, fontweight = 'bold', alpha = 0.6)
df_mode = df[(df['popularity']) & (df['explicit'] == False)]
ax1[1,1].hist(x= df_mode['popularity'], bins=15, density=False, orientation='vertical', histtype = 'barstacked', rwidth = 0.75)
ax1[1,1].set_title ('Popularity histogram for explicit = False', fontsize = 15, fontweight = 'bold', alpha = 0.6)
ax1[1,1].grid(True)

ax1[1,2].set_ylabel('Count', fontsize = 12, fontweight = 'bold', alpha = 0.6 )
ax1[1,2].set_xlabel('popularity', fontsize = 12, fontweight = 'bold', alpha = 0.6)
ax1[1,2].hist(x= df['popularity'], bins=15, density=False, orientation='vertical', histtype = 'barstacked', rwidth = 0.75)
ax1[1,2].set_title ('Popularity histogram', fontsize = 15, fontweight = 'bold', alpha = 0.6)
ax1[1,2].grid(True)
# Out:
# C:\Users\velas\AppData\Local\Temp\ipykernel_23436\309257735.py:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   mpl.style.use('seaborn-deep')

# %%
# SCATTERPLOTS
mpl.style.use('seaborn-deep')

rows = 3
cols = 4
fig,ax1 = plt.subplots(nrows = rows, ncols = cols, figsize = (30,15))

columns = ['duration_ms', 'danceability', 'energy', 'key', 'loudness', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature']

counter = 0
for row in range(rows):
    for col in range(cols):
        if counter <= len(columns) - 1:
            ax1[row,col].set_ylabel('Popularity', fontsize = 15, fontweight = 'bold', alpha = 0.6 )
            #ax1[row,col].set_title ('Popularity as a function of ' + columns[counter], fontsize = 10, fontweight = 'bold', alpha = 0.6)
            ax1[row,col].grid(True)
            ax1[row,col].axhline(y = df.popularity.median(), c='red', ls='--', lw=2)
            if columns[counter] != 'duration_ms':
                sns.scatterplot(ax = ax1[row,col], data = df, x= df[columns[counter]], y = df['popularity'], s = 5)
                ax1[row,col].set_xlabel(columns[counter], fontsize = 15, fontweight = 'bold', alpha = 0.6)
                ax1[row,col].axvline(x = df[columns[counter]].median(), c='red', ls='--', lw=2)
            else:
                sns.scatterplot(ax = ax1[row,col], data = df, x= df[columns[counter]]/1000, y = df['popularity'], s = 5)
                ax1[row,col].set_xlabel('duration [sec]', fontsize = 15, fontweight = 'bold', alpha = 0.6)
                ax1[row,col].set_xlim(0,1000)
                ax1[row,col].axvline(x = df[columns[counter]].median()/1000, c='red', ls='--', lw=2)
            
            counter += 1

plt.yticks(fontsize = 15)
# Out:
# C:\Users\velas\AppData\Local\Temp\ipykernel_23436\3874637478.py:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   mpl.style.use('seaborn-deep')
# (array([-20.,   0.,  20.,  40.,  60.,  80., 100., 120.]),
#  [Text(0, -20.0, '−20'),
#   Text(0, 0.0, '0'),
#   Text(0, 20.0, '20'),
#   Text(0, 40.0, '40'),
#   Text(0, 60.0, '60'),
#   Text(0, 80.0, '80'),
#   Text(0, 100.0, '100'),
#   Text(0, 120.0, '120')])

# %% [markdown]
# Even though lower values of popularity can be seen for a wide range of the remaining variables, higher values of popularity seem to be achieved for tracks with:
# - Higher values of danceability, energy and time_signature
# - Values of duration, loudness, speechiness, liveness and time signature close to median values
# - Lower values of speechiness, acousticeness, instrumentalness, and liveness
#
# This is also aligned with what is shown in popularity histogram, as the second highest popularity range is close to zero (close to 12000 values). Therefore, it might be better to define and predict a track popularity range, rather than it's popularity rating.

# %%
df.describe()
# Out:
#          popularity   duration_ms  danceability        energy           key  \
# count  89741.000000  8.974100e+04  89741.000000  89741.000000  89741.000000
# mean      33.207196  2.291418e+05      0.562166      0.634458      5.283549
# std       20.574270  1.129477e+05      0.176691      0.256605      3.559897
# min        0.000000  0.000000e+00      0.000000      0.000000      0.000000
# 25%       19.000000  1.730400e+05      0.450000      0.457000      2.000000
# 50%       33.000000  2.132930e+05      0.576000      0.676000      5.000000
# 75%       49.000000  2.642930e+05      0.692000      0.853000      8.000000
# max      100.000000  5.237295e+06      0.985000      1.000000     11.000000
#
#            loudness          mode   speechiness  acousticness  \
# count  89741.000000  89741.000000  89741.000000  89741.000000
# mean      -8.499004      0.636966      0.087442      0.328289
# std        5.221490      0.480877      0.113277      0.338321
# min      -49.531000      0.000000      0.000000      0.000000
# 25%      -10.322000      0.000000      0.036000      0.017100
# 50%       -7.185000      1.000000      0.048900      0.188000
# 75%       -5.108000      1.000000      0.085900      0.625000
# max        4.532000      1.000000      0.965000      0.996000
#
#        instrumentalness      liveness       valence         tempo  \
# count      89741.000000  89741.000000  89741.000000  89741.000000
# mean           0.173413      0.216970      0.469477    122.058316
# std            0.323848      0.194884      0.262864     30.117532
# min            0.000000      0.000000      0.000000      0.000000
# 25%            0.000000      0.098200      0.249000     99.264000
# 50%            0.000058      0.132000      0.457000    122.013000
# 75%            0.097600      0.279000      0.682000    140.077000
# max            1.000000      1.000000      0.995000    243.372000
#
#        time_signature
# count    89741.000000
# mean         3.897427
# std          0.453435
# min          0.000000
# 25%          4.000000
# 50%          4.000000
# 75%          4.000000
# max          5.000000

# %%
# Out:
# 5.8e-05
